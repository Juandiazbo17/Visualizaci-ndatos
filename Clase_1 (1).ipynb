# %% [markdown]
# # Clase 1: Introduccion a Python

# %%
print ("Hola")
# Out:
# Hola

# %% [markdown]
# ### Cargando libreriras

# %%
import numpy as np

# %%
x = 50
numeros_aleatorios = np.random.rand(x)

numeros_aleatorios
# Out:
# array([0.60958919, 0.52613614, 0.64359265, 0.86649109, 0.02734942,
#        0.15401838, 0.19199653, 0.62498852, 0.25014219, 0.41800281,
#        0.3076774 , 0.88177085, 0.54803874, 0.51522064, 0.64541329,
#        0.63640923, 0.21921899, 0.09326174, 0.94975362, 0.0878164 ,
#        0.89196987, 0.01726015, 0.73474665, 0.10277372, 0.02575017,
#        0.24448212, 0.64375831, 0.63372652, 0.9399447 , 0.64659904,
#        0.24094284, 0.49709844, 0.97760076, 0.33727595, 0.84738204,
#        0.09269255, 0.74574304, 0.40825608, 0.96448233, 0.51805884,
#        0.63960727, 0.47135259, 0.94243257, 0.43785442, 0.05743612,
#        0.25957224, 0.48404003, 0.24207552, 0.59104494, 0.16640463])

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %% [markdown]
# ## Tpos de los datos

# %%
import math

# %%
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
type(-3)
# Out:
# int

# %%
x = "nombre1"
x
# Out:
# 'nombre1'

# %%
type (x)
# Out:
# str

# %%
numbers = [1, 2, 3, 4, 5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type (numbers)
# Out:
# list

# %%
sum_numbers = sum(numbers)
sum_numbers
# Out:
# 15

# %%
lenth = len(numbers)
lenth
# Out:
# 5

# %%
promedio = sum_numbers/lenth
promedio
# Out:
# 3.0

# %%
type(3/5)
# Out:
# float

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
type(math.pi)
# Out:
# float

# %%
type("math.pi")
# Out:
# str

# %%
numbers = [math.pi, 3/5, 4.0, "nombre", True]
numbers
# Out:
# [3.141592653589793, 0.6, 4.0, 'nombre', True]

# %%
type(False)
# Out:
# bool

# %%
type("False")
# Out:
# str

# %%
print(None)
# Out:
# None

# %%
type(None)
# Out:
# NoneType

# %%
x = 6
y = 8 
if x < y:
    print("{} es menor que {}".format(x,y))
else:
    print(x, "es mayor que", y)
# Out:
# 6 es menor que 8

# %%
unaLista = [True, 6<5, 1==3, None is None ]
unaLista
# Out:
# [True, False, False, True]

# %% [markdown]
# ## el uso for loop

# %%
for element in unaLista:
    print(element,"\t",type(element))
# Out:
# True 	 <class 'bool'>
# False 	 <class 'bool'>
# False 	 <class 'bool'>
# True 	 <class 'bool'>
